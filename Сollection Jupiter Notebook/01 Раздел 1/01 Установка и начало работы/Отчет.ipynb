# %% [markdown]
# # Установка и начало работы

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <p style="text-align:center">Рисунок 1.1 - Окно «Anaconda Navigator», установлена «Notebook»</p>

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <p style="text-align:center">Рисунок 1.2 - Результат запушено веб-сайт «Notebook»</p>

# %% [markdown]
# ---

# %% [markdown]
# # Пример

# %%
# Сложение a + b
9 + 3
# Out:
# 12

# %%
# Вычитание а-Ь
9 - 3
# Out:
# 6

# %%
# Умножение а*Ь
9 * 3
# Out:
# 27

# %%
# Деление а/Ь
9 / 3
# Out:
# 3.0

# %%
# Неполное частное от деления а//Ь
8 // 3 # 8//3 = 2.665 -> 2
# Out:
# 2

# %%
# Остаток от деления а%Ь
8 % 3 # (8 > 3)> 8 - 3 = 5, (5 > 3)> 5 - 3 = 2, (2 < 3)> 2.
# Out:
# 2

# %%
# Изменение знака числа -а
-9
# Out:
# -9

# %%
# Модуль числа abs(a)
abs(-9)
# Out:
# 9

# %%
# Возведение в степень a**b
3 ** 3
# Out:
# 27

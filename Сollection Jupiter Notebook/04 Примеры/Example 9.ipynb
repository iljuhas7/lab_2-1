# %% [markdown]
# # Пример 9

# %%
import matplotlib as mpl # библиотека: matplotlib как mpl

# %%
import matplotlib.pyplot as plt # библиотека: pyplot как plt

# %%
import matplotlib.ticker as tk # библиотека: ticker как tk

# %%
import matplotlib.animation as mpla  # библиотека: animation как mpla

# %%
import numpy as np # библиотека: numpy как mpl (треб.)

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4])
plt.ylabel('Некоторые цифры')
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
plt.axis([0, 6, 0, 20])
plt.show()

# %%
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %%
X = np.linspace(0, 2*np.pi, 100)
Y = np.cos(X)
fig, ax = plt.subplots()
ax.plot(X, Y, color='green')
#fig.savefig("figure.pdf") # сохранить файла "figure"
fig.show()

# %%
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('Вход А')
plt.ylabel('Вход Б')
plt.show()

# %%
names = ['А', 'Б', 'В']
values = [1, 10, 100]

plt.figure(figsize=(9, 3))

plt.subplot(131)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
plt.suptitle('Категориальное построение графика')
plt.show()

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure()
plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# Гистограмма данных
n, bins, patches = plt.hist(x, 50, density=True, facecolor='g', alpha=0.75)

plt.xlabel('Сообразительность')
plt.ylabel('Вероятность')
plt.title('Гистограмма IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %%
np.random.seed(19680801)
y = np.random.normal(loc=0.5, scale=0.4, size=1000)
y = y[(y > 0) & (y < 1)]
y.sort()
x = np.arange(len(y))

plt.figure()

# Линейный
plt.subplot(221)
plt.plot(x, y)
plt.yscale('linear')
plt.title('Линейный')
plt.grid(True)

# Лог
plt.subplot(222)
plt.plot(x, y)
plt.yscale('log')
plt.title('Лог')
plt.grid(True)

# Симметричный логарифм
plt.subplot(223)
plt.plot(x, y - y.mean())
plt.yscale('symlog', linthresh=0.01)
plt.title('Симметричный логарифм')
plt.grid(True)

# Логистическая регрессия
plt.subplot(224)
plt.plot(x, y)
plt.yscale('logit')
plt.title('Логистическая регрессия')
plt.grid(True)
plt.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=0.95, hspace=0.25, wspace=0.35)

plt.show()

# %%
methods = [None, 'none', 'nearest', 'bilinear', 'bicubic', 'spline16',
           'spline36', 'hanning', 'hamming', 'hermite', 'kaiser', 'quadric',
           'catrom', 'gaussian', 'bessel', 'mitchell', 'sinc', 'lanczos']

# Fixing random state for reproducibility
np.random.seed(19680801)

grid = np.random.rand(4, 4)

fig, axs = plt.subplots(nrows=3, ncols=6, figsize=(9, 6),
                        subplot_kw={'xticks': [], 'yticks': []})

for ax, interp_method in zip(axs.flat, methods):
    ax.imshow(grid, interpolation=interp_method, cmap='viridis')
    ax.set_title(str(interp_method))

plt.tight_layout()
plt.show()

# %%
    xmin = -10.0
    xmax = 10.0
    xcount = 201

    xvals = np.linspace(xmin, xmax, xcount)
    yvals = np.sinc(xvals)

    figure = plt.figure()
    axes = figure.add_subplot(1, 1, 1)

    plt.plot(xvals, yvals)
    axes.set_xlim(xmin, xmax)

    # !!! Создаем экземпляр класса, который будет отвечать за расположение рисок
    locator = tk.NullLocator()

    # !!! Установим локатор для главных рисок
    axes.xaxis.set_major_locator(locator)

    axes.grid()
